# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook Data Science tools and Ecosystem are summarized.

# %% [markdown]
# **Objectives:**
# * Listing common programming languages and libraries Data Scientists use
# * Learn how to create tables using markdown
# * Learn how to add documentation in code cells using the '#' symbol

# %% [markdown]
# # Some of the popular languages data scientists used are:
#
# 1. Python
# 2. R
# 3. Java

# %% [markdown]
# Some of the common libraries they use include:
#
# 1. ggplot
# 2. dplyr
# 3. GGally

# %% [markdown]
# |Data Science Tools|
# | -----------------|
# |Jupyer Notebooks |
# | Rstudio |
# | VScode |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
# This is simple arithmetic expression to multiply then add integers.
(3*4)+5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60 
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
#
# Benjamin
